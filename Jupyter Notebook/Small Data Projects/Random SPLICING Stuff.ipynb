# %%
letters = ["A","B","C","D","E","F","G","H","I","J"]

# %%
letters
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters [ : ]
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters[2:]
# Out:
# ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters[:7]
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
letters[2:7]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
letters[-8:-3]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
#--- advanced slicing

# %%
letters[2:9]
# Out:
# ['C', 'D', 'E', 'F', 'G', 'H', 'I']

# %%
letters[2:9:2]
# Out:
# ['C', 'E', 'G', 'I']

# %%
letters
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
letters[::3]
# Out:
# ['A', 'D', 'G', 'J']

# %% [markdown]
# ----

# %%
letters[::-1]
# Out:
# ['J', 'I', 'H', 'G', 'F', 'E', 'D', 'C', 'B', 'A']

# %%
letters[2:7]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
letters[2:7:1]
# Out:
# ['C', 'D', 'E', 'F', 'G']

# %%
letters[2:7:2]
# Out:
# ['C', 'E', 'G']

# %%
letters[6:1:-1]
# Out:
# ['G', 'F', 'E', 'D', 'C']

# %%
letters[6:1:-2]
# Out:
# ['G', 'E', 'C']

# %% [markdown]
# -----

# %%
#tuple = immutable list

# %%
t1 = (345, 674, 934)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-4065f514882c> in <module>()
# ----> 1 t1[1] = 45
#
# TypeError: 'tuple' object does not support item assignment
