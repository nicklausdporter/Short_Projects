# %%
from random import randint

board = []

for x in range(0, 5):
  board.append(["O"] * 5)

def print_board(board):
  for row in board:
    print " ".join(row)
#this code above removed the boundaries on the Os
print_board(board)

def random_row(board):
  return randint(0, len(board) - 1)
def random_col(board):
  return randint(0, len(board[0]) - 1)

ship_row = random_row(board)
ship_col = random_col(board)
#print ship_row #add print ship_row here to see location
#print ship_col #add print ship_col to see location must add 
3
#everything above here just sets up board and ship

for turn in range(4): 
  print "Turn", turn + 1
  guess_row = int(raw_input("Guess Row: "))
  guess_col = int(raw_input("Guess Col: "))

  if guess_row == ship_row and guess_col == ship_col:
    print "Congratulations! You sank my battleship!" 
    break
  else:
    if guess_row not in range(5) or \
      guess_col not in range(5):
      print "Oops, that's not even in the ocean."
    elif board[guess_row][guess_col] == "X":
      print( "You guessed that one already." )
    else:
      print "You missed my battleship!"
      board[guess_row][guess_col] = "X"
      if turn == 3:
        print "Game Over",
        print ship_row,
        print ship_col
    print_board(board)
# Out:
# O O O O O
# O O O O O
# O O O O O
# O O O O O
# O O O O O
# Turn 1
# Guess Row: 1
# Guess Col: 3
# You missed my battleship!
# O O O O O
# O O O X O
# O O O O O
# O O O O O
# O O O O O
# Turn 2
# Guess Row: 1
# Guess Col: 2
# You missed my battleship!
# O O O O O
# O O X X O
# O O O O O
# O O O O O
# O O O O O
# Turn 3
# Guess Row: 3
# Guess Col: 4
# You missed my battleship!
# O O O O O
# O O X X O
# O O O O O
# O O O O X
# O O O O O
# Turn 4
# Guess Row: 2
# Guess Col: 4
# You missed my battleship!
# Game Over 1 1
# O O O O O
# O O X X O
# O O O O X
# O O O O X
# O O O O O

# %%
from random import randint

secret_number = randint(0,101)
for guess in range(10):
    print "Guess:", guess + 1
    guess_int = int(raw_input("Guess Number: "))
    
    if guess_int == secret_number:
        print "Congratulations! You guessed the secret number!"
        break
    else:
        if guess == 9:
            print "Oops, You used your last guess! Game Over!",
        elif guess_int not in range(101):
            print "Oops, thats not between 0 and 100!"
        elif guess_int < secret_number:
            print "Your guess is too low!"
        else: 
            guess_int > secret_number
            print "Your guess is too High!"
       
            #guess == 9
            #print "Oops, You used your last guess! Game Over!",
            #print secret_number
# Out:
# Guess: 1
# Guess Number: 50
# Your guess is too low!
# Guess: 2
# Guess Number: 75
# Your guess is too High!
# Guess: 3
# Guess Number: 65
# Your guess is too High!
# Guess: 4
# Guess Number: 55
# Your guess is too High!
# Guess: 5
# Guess Number: 53
# Your guess is too High!
# Guess: 6
# Guess Number: 52
# Congratulations! You guessed the secret number!
